# %% [markdown]
# # Data Visualization: From Non-Coder to Coder
# 1. [Tutorial Link](https://www.kaggle.com/alexisbcook/hello-seaborn)

# %% [markdown]
# Datasets used in this notebook can be found at https://www.kaggle.com/alexisbcook/data-for-datavis

# %% [markdown]
# In this tutorial we will be using [seaborn](https://seaborn.pydata.org/index.html) to create plots from data.

# %%
# setup the notebook for data visualization
# import modules
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ### Load the Data

# %%
# specify the path
path = "data_for_02_Data_Visualization/fifa.csv"

# Read the file into a variable 
fifa_data = pd.read_csv(path, index_col = "Date", parse_dates = True)

# %% [markdown]
# ### Examine the Data

# %%
# print the first 5 rows of the data
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# ### Plot the Data

# %%
# To generate a line chart
# Set width and height of figure
plt.figure(figsize=(16, 6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)
# Out:
# /home/mahendra/anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Exercises for this tutorial solved at https://www.kaggle.com/mahendrabishnoi2/exercise-hello-seaborn

# %% [markdown]
# ## Line Charts
# 2. [Tutorial link](https://www.kaggle.com/alexisbcook/line-charts)

# %%
# First of all we will setup our notebook for plotting
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# The Dataset for this tutorial (Line Charts) tracks global daily streams on music streaming service Spotify. We will focus on five popular songs from 2017-18. <br/>
# 1. "Shape of You", by Ed Sheeran
# 2. "Despacito", by Luis Fonzi
# 3. "Something Just Like This", by The Chainsmokers and Coldplay
# 4. "HUMBLE.", by Kendrick Lamar
# 5. "Unforgettable", by French Montana

# %% [markdown]
# ### Load the Data

# %%
# specify the path to dataset
path = "data_for_02_Data_Visualization/spotify.csv"

# Load the file 'spotify.csv' into a variable
spotify_data = pd.read_csv(path, index_col = "Date", parse_dates = True)

# %% [markdown]
#  ### Examine the Data

# %%
# print first five rows of the data
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# Here we can see that first date is 6th January 2017 and Shape of You was streamed `12287078` times on 6th Jan. <br/>
# We are seeing `NaN` for songs other than `Shape of You` because they released later. <br/>
# > Empty entries appear as `NaN` which is short for Not a "Number"

# %%
# print last five rows of the data
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# ### Plot the Data

# %%
# Line chart showing daily global stream of each song
sns.lineplot(data = spotify_data)

# %%
# We can specify some additional values such as size of figure

# Specify figure size
plt.figure(figsize=(17, 6))

# Add a title to the figure
plt.title("Daily streams of popular songs in 2017-18")

# Create line chart
sns.lineplot(data = spotify_data)

# %% [markdown]
# ### Plot a subset of the Data
# We have learned how to plot all the columns of data. Now we will learn how to plot selected columns from the data.

# %%
# create a list of all columns 
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Now we will plot first two columns

# set figure size 
plt.figure(figsize=(17, 6))

# set title
plt.title("Daily streams of popular songs in 2017-18")

# plot first column "Shape of You"
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# plot second column "Despacito"
sns.lineplot(data=spotify_data["Despacito"], label="Despacito")

# set xlabel
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# Exercises of this tutorial are solved [here](https://www.kaggle.com/mahendrabishnoi2/exercise-line-charts)

# %% [markdown]
# ## Bar Charts and Heat Map
# 3. [Tutorial Link](https://www.kaggle.com/alexisbcook/bar-charts-and-heatmaps)

# %% [markdown]
# ### Setup Notebook

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# In this tutorial we will work with a dataset from US Department of Transportation that tracks flight delays.

# %% [markdown]
# ### Load the Data

# %%
# specify path of dataset
path = "data_for_02_Data_Visualization/flight_delays.csv"

# read data from file into a variable
flight_data = pd.read_csv(path, index_col="Month")

# %% [markdown]
# ### Examine the Data

# %%
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %% [markdown]
# ### Bar Chart
# Create a bar chart for "Spirit Airlines" (Code: "NK") flight dealys by month

# %%
# set figure size
plt.figure(figsize=(12, 6))

# set tilte
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Create Bar Chart using seaborn
sns.barplot(x=flight_data.index, y=flight_data.NK)

# Add label for vertical axis
plt.ylabel("average arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'average arrival delay (in minutes)')

# %% [markdown]
# ### Heat Map

# %%
# set width and height of figure
plt.figure(figsize=(15, 6))

# Add title
plt.title("Average Arrival Delay for each Airline, by Month")

# Create heatmap showing average arrival delay 
sns.heatmap(data=flight_data, annot=True)

# Add label for horizontal axis 
plt.xlabel("Airline")
# Out:
# Text(0.5, 33.0, 'Airline')

# %% [markdown]
# Exercises of this tutorial are solved [here](https://www.kaggle.com/mahendrabishnoi2/exercise-bar-charts-and-heatmaps)

# %% [markdown]
# ## Scatter Plots
# 4. [Tutorial Link](https://www.kaggle.com/alexisbcook/scatter-plots)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Load the Data
# In this tutorial we will work with (synthetic) dataset of insurance charges to understand why some customers pay more than others

# %%
# path of file to be read
path = "data_for_02_Data_Visualization/insurance.csv"

# read file into a variable
insurance_data = pd.read_csv(path)

# %%
# print first five rows
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Create Scatter Plot
# To create a simple Scatter Plot, we use `sns.scatterplot` command and specify values for
# 1. horizontal axis (x-axis)
# 2. vertical axis (y-axis)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# Scatter Plot shows that `bmi` and `charges` are **positively correlated** because normally people with higer bmi tend to pay more charges.
#
# To double check we will add **regression line** (line that best fits the data). We can do so by `sns.regplot` command

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# ### Color coded Scatter Plots
# We can use scatter plot to show relationship between **three** variables. One way to do this is by color coding the points.
#
# To understand how smoking affects the relationship between BMI and insurance costs, we can color code the points by `smoker` and plot `bmi` and `charges` on axes.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])

# %% [markdown]
# Above plot shows that non-smokers tend to pay much less compared to smokers with increasing bmi.
#
# We can use `sns.lmplot` command to plot two regression lines corresponding to smokers and non-smokers respectively.

# %%
plt.figure(figsize=(10, 6))
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %% [markdown]
# From above plot we can confirm our statement as regression line corresponding to smoker has much higer slope than non-smoker.

# %% [markdown]
# ### Categorical Scatter Plot
# command: `sns.swarmplot` <br/>
# Scatter plots are use to show relationship between two continuous variables. Categorical scatter plots feature categorical variable such as `smoker`, `region` etc. on one of the main axes.

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])

# %% [markdown]
# Exercises for this tutorial are solved [here](https://www.kaggle.com/mahendrabishnoi2/exercise-scatter-plots)

# %% [markdown]
# ## Distributions
# **Histograms and Density Plots**
# 5. [Tutorial Link](https://www.kaggle.com/alexisbcook/distributions)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Load and Examine the Data

# %%
# path of file to be read
path = "data_for_02_Data_Visualization/iris.csv"

# Read the file into a variable
iris_data = pd.read_csv(path, index_col="Id")

# print first five rows of the data
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ### Histogram
# Create a histogram to see how petal length varies in iris flowers. command: `sns.distplot`

# %%
sns.distplot(a=iris_data["Petal Length (cm)"], kde=False)

# a = choose the column we'd like to plot

# %% [markdown]
# ### Density Plot
# Known as **kernel density estimate (KDE)** plot. Can think of it as smoothened histogram.
#
# command = `sns.kdeplot` and use `shade=True` to color area below the curve.

# %%
# KDE plot
sns.kdeplot(data=iris_data["Petal Length (cm)"], shade=True)

# %% [markdown]
# ### 2D KDE Plot
# We are not restricted to a single column when creating KDE plot. We can 2D KDE plot with `sns.jointplot` command.

# %%
sns.jointplot(x=iris_data["Sepal Width (cm)"], y=iris_data["Petal Width (cm)"], kind="kde")

# %% [markdown]
# In the above plot the color coding shows us likeliness of seeing different combinations of sepal width and petal width. Darker color means more likeliness.

# %% [markdown]
# ### Color coded plots

# %%
# Paths of files to be read
iris_set_path = "data_for_02_Data_Visualization/iris_setosa.csv"
iris_ver_path = "data_for_02_Data_Visualization/iris_versicolor.csv"
iris_vir_path = "data_for_02_Data_Visualization/iris_virginica.csv"

# Read the files into variables
iris_set_data = pd.read_csv(iris_set_path, index_col="Id")
iris_ver_data = pd.read_csv(iris_ver_path, index_col="Id")
iris_vir_data = pd.read_csv(iris_vir_path, index_col="Id")

# print first five rows of iris_versicolor data
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %%
# set width and height of figure
plt.figure(figsize=(10, 6))

# Histogram for each species
sns.distplot(a=iris_set_data["Petal Length (cm)"], kde=False, label="Iris-setosa")
sns.distplot(a=iris_ver_data["Petal Length (cm)"], kde=False, label="Iris-versicolor")
sns.distplot(a=iris_vir_data["Petal Length (cm)"], kde=False, label="Iris-virginia")

# Add title
plt.title("Histogram of Petal Length (in cm), by species")

# For legend to show
plt.legend()

# %%
# set width and height of figure
plt.figure(figsize=(10, 6))

# kde plot for each species
sns.kdeplot(data=iris_set_data["Petal Length (cm)"], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data["Petal Length (cm)"], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data["Petal Length (cm)"], label="Iris-virginia", shade=True)

# Add title
plt.title("KDE of Petal Length (in cm), by species")
# Out:
# Text(0.5, 1.0, 'KDE of Petal Length (in cm), by species')

# %% [markdown]
# Exercises of this tutorial are solved [here](https://www.kaggle.com/mahendrabishnoi2/exercise-distributions)

# %% [markdown]
# ## Choosing Plot Types and Custom Styles
# 6. [Tutorial Link](https://www.kaggle.com/alexisbcook/choosing-plot-types-and-custom-styles)
#
# So far we have learned:
# <img src="https://i.imgur.com/2VmgDnF.png"/>

# %% [markdown]
# To decide which chart to use when describing the data, charts can be divided in three types:
#
# - Trends - A trend is defined as a pattern of change.
#     - `sns.lineplot` - **Line charts** are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
# - Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
#     - `sns.barplot` - **Bar charts** are useful for comparing quantities corresponding to different groups.
#     - `sns.heatmap` - **Heatmaps** can be used to find color-coded patterns in tables of numbers.
#     - `sns.scatterplot` - **Scatter plots** show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#     - `sns.regplot` - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#     - `sns.lmplot` -  This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#     - `sns.swarmplot` - **Categorical scatter plots** show the relationship between a continuous variable and a categorical variable.
# - Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#     - `sns.distplot` - **Histograms** show the distribution of a single numerical variable.
#     - `sns.kdeplot` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#     - `sns.jointplot` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# ### Changing Styles with Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# path of file to be read
path = "data_for_02_Data_Visualization/spotify.csv"

# read file into a variable
spotify_data = pd.read_csv(path, index_col="Date", parse_dates=True)

# create line chart
plt.figure(figsize=(15, 8))
sns.lineplot(data=spotify_data)

# %%
# Now we will change style(theme) of above plot
sns.set_style('dark')

# create line chart
plt.figure(figsize=(15, 8))
sns.lineplot(data=spotify_data)

# %% [markdown]
# Five different themes supported by seaborn
# 1. `"darkgrid"`
# 2. `"whitegrid"`
# 3. `"dark"`
# 4. `"white"`
# 5. "`ticks"`

# %% [markdown]
# Exercises of this tutorial are solved [here](https://www.kaggle.com/mahendrabishnoi2/exercise-choosing-plot-types-and-custom-styles)
